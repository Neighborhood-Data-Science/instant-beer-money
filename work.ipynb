# %%
import requests

# %%
site = "https://www.ayetstudios.com/offers/web_offerwall/2693?external_identifier=fsid-2308045-607783a635"

# %%
page = requests.get(site)

# %%
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no, shrink-to-fit=no, viewport-fit=cover" name="viewport"/>
# <meta content="" name="description"/>
# <meta content="" name="author"/>
# <link href="https://www.ayetstudios.com/favicon.ico" rel="icon"/>
# <title>Complete any offer to earn Coins</title>
# <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700,900&amp;display=swap" rel="stylesheet"/>
# <link href="https://d1mys92jzce605.cloudfront.net/offerwall/css/vendor.3edd4477-9ba3-4e7d-a5d7-6c1cb6061cd2.css" rel="stylesheet"/>
# <style>
#     #content {
#         background: transparent;
#     }
#
#     .tabbable-line > .tab-content {
#         background-color: transparent;
#     }
#
#         body{
#         font-size: 16px;
#     }
#     #offer-tabs,#status-tabs{
#         font-size: 0.9em;
#     }
#
#
#
#
# ...
